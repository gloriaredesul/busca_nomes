# %% [markdown]
# <a href="https://colab.research.google.com/github/gloriaredesul/busca_nomes/blob/main/verificador_de_pagamentos_emdia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📌 Passo 1: Importar bibliotecas necessárias
import pandas as pd
from datetime import datetime
from google.colab import files
import io

# 📌 Passo 2: Upload da planilha
print("📁 Faça o upload da planilha (.xlsx ou .csv):")
uploaded = files.upload()

# 📌 Passo 3: Leitura da planilha
filename = list(uploaded.keys())[0]

if filename.endswith('.xlsx'):
    df = pd.read_excel(io.BytesIO(uploaded[filename]))
elif filename.endswith('.csv'):
    df = pd.read_csv(io.BytesIO(uploaded[filename]))
else:
    raise ValueError("Formato de arquivo não suportado. Envie .xlsx ou .csv")

# 📌 Passo 4: Conversão das datas (mantendo colunas com inicial maiúscula)
df['Vencimento'] = pd.to_datetime(df['Vencimento'], errors='coerce')
df['Pagamento'] = pd.to_datetime(df['Pagamento'], errors='coerce')

# 📌 Passo 5: Verificação de pagamentos em dia (mesmo mês e ano)
df['pagamento_em_dia'] = (
    (df['Vencimento'].dt.month == df['Pagamento'].dt.month) &
    (df['Vencimento'].dt.year == df['Pagamento'].dt.year)
)

# 📌 Passo 6: Filtrar apenas os pagamentos em dia
pagamentos_em_dia = df[df['pagamento_em_dia']]

# 📌 Passo 7: Exibir resultado
print("✅ Pagamentos realizados no mesmo mês e ano do vencimento:")
display(pagamentos_em_dia)
# Out:
# 📁 Faça o upload da planilha (.xlsx ou .csv):
#      <input type="file" id="files-c935b34e-addd-4f8a-84f7-0a8dd0637e94" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c935b34e-addd-4f8a-84f7-0a8dd0637e94">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
